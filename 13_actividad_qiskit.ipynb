# %%
# !pip install qiskit qiskit[visualization] qiskit_aer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 95.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 9.8 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=8474bbaf1b739bf91294445842279c7e8e71a9b30513a4aa35897f152fad7405
#   Stored in directory: /root/.cache/pip/wheels/b1/7a/33/9fdd892f784ed4afda62b685ae3703adf4c91aa0f524c28f03
# Successfully built pylatexenc
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from qiskit import QuantumCircuit
from qiskit import transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %%
# numero de qbits
n = 2

# %%
qc = QuantumCircuit(n + 1, n)
qc.h(range(n))
qc.x(n)
qc.h(n)
qc.barrier()
qc.cx(0,2)
qc.cx(0,1)
qc.barrier()
qc.h(range(n))
qc.barrier()
qc.measure(range(n), range(n))

qc.draw('mpl')

# %%
backend = AerSimulator()
shots = 1
qc_tra = transpile(qc, backend=backend)
job = backend.run(qc_tra, shots = shots)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'01': 1}

# %%
qc = QuantumCircuit(n + 1, n)
qc.h(range(n))
qc.x(n)
qc.h(n)
qc.barrier()
qc.x(2)
qc.barrier()
qc.h(range(n))
qc.barrier()
qc.measure(range(n), range(n))

qc.draw('mpl')

# %%
backend = AerSimulator()
shots = 1
qc_tra = transpile(qc, backend=backend)
job = backend.run(qc_tra, shots = shots)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00': 1}

# %%
n = 3
qc = QuantumCircuit(n + 1, n)
qc.h(range(n))
qc.x(n)
qc.h(n)
qc.barrier()
qc.cx(0,3)
qc.cx(0,2)
qc.cx(0,1)
qc.barrier()
qc.h(range(n))
qc.barrier()
qc.measure(range(n), range(n))

qc.draw('mpl')

# %%
backend = AerSimulator()
shots = 100
qc_tra = transpile(qc, backend=backend)
job = backend.run(qc_tra, shots = shots)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'001': 100}

# %%
n = 3
qc = QuantumCircuit(n + 1, n)
qc.h(range(n))
qc.x(n)
qc.h(n)
qc.barrier()
qc.x(n)
qc.barrier()
qc.h(range(n))
qc.barrier()
qc.measure(range(n), range(n))

qc.draw('mpl')

# %%
backend = AerSimulator()
shots = 1
qc_tra = transpile(qc, backend=backend)
job = backend.run(qc_tra, shots = shots)
counts = job.result().get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'000': 1}
